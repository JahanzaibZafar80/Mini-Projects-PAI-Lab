# %%
x_cap= int(input("enter x capactity"))
y_cap= int(input("enter y capactity"))
x=0
y=0
Goal=2
while True:
    user=int(input('\n1.x fill untill fill \n2.y fill untill fill\n3.x empty\n4.y empty\n5.x into y untill x empty\n6.x into y untill y full\n7.y into x untill y empty\n8.y into x untill x full\nenter ypur choice='))
    if x==Goal or y ==Goal:
        print("Goal Found")
        break
    if user==1:
        x=x_cap
        print("x =",x,", y=",y)
    elif user==2:
        y=y_cap
        print("x =",x,", y=",y)
    elif user==3:
        x=0
        print("x =",x,", y=",y)
    elif user==4:
        y=0
        print("x =",x,", y=",y)
    elif user==5:
        
        i=0
        while x!=0 and y<y_cap:
            transfer=min(x,y_cap-y)
            y+=transfer
            x-=transfer
            i+=1
        print("x =",x,", y=",y)
            
        
    elif user==6:
        i=0
        while x!=0 and y<y_cap:
            transfer=min(x,y_cap-y)
            y+=transfer
            x-=transfer
            i+=1
        print("x =",x,", y=",y)
    elif user==7:
        
        i=0
        while y!=0 and x<x_cap:
            transfer=min(y,x_cap-x)
            x+=transfer
            y-=transfer
            i+=1
        print("x =",x,", y=",y)
    elif user==8:
        
        i=0
        while y!=0 and x<x_cap:
            transfer=min(y,x_cap-x)
            x+=transfer
            y-=transfer
            i+=1
        print("x =",x,", y=",y)
    elif user==9:
        break
    else:
        print("invalid input ")
